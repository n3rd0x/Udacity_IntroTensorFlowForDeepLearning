# %%
# Education - Udacity "Intro to TensorFlow for Deep Learning"
# Module: Forecasting with Recurrent Neural Network (Sequence to Sequence)
# REF: https://colab.research.google.com/github/tensorflow/examples/blob/master/courses/udacity_intro_to_tensorflow_for_deep_learning/l08c06_forecasting_with_rnn.ipynb

# %%
# Import packages.
from __future__ import absolute_import, division, print_function, unicode_literals
import numpy as np
import matplotlib.pyplot as plt

# Using version 2.x of Tensorflow.
try:
  # Use the %tensorflow_version magic if in colab.
  # %tensorflow_version 2.x
except Exception:
  pass

# Tensorflow.
import tensorflow as tf

# Print Tensorflow version.
print('TensorFlow Version:', tf.__version__)
# Out:
# TensorFlow 2.x selected.
# TensorFlow Version: 2.1.0

# %%
# ====================
# Helper Function
# ====================
# Plot serie.
def plot_series(time, series, format="-", start=0, end=None, label=None):
  plt.plot(time[start:end], series[start:end], format, label=label)
  plt.xlabel("Time")
  plt.ylabel("Value")
  if label:
    plt.legend(fontsize=14)
  plt.grid(True)


# Trend.
def trend(time, slope=0):
  return slope * time


# Seasonal pattern.
def seasonal_pattern(season_time):
  # Just an arbitrary pattern.
  return np.where(season_time < 0.4, np.cos(season_time * 2 * np.pi), 1 / np.exp(3 * season_time))


# Seasonality.
def seasonality(time, period, amplitude=1, phase=0):
  # Repeats the same pattern at each period.
  season_time = ((time + phase) % period) / period
  return amplitude * seasonal_pattern(season_time)


# White noise.
def white_noise(time, noise_level=1, seed=None):
  rnd = np.random.RandomState(seed)
  return rnd.randn(len(time)) * noise_level


# Dataset for machine learning.
def window_dataset(series, window_size, batch_size = 32, shuffle_buffer = 1000):
  # Create a dataset of tensors.
  dataset = tf.data.Dataset.from_tensor_slices(series)

  # Drop remaining values so we get same size.
  dataset = dataset.window(window_size + 1, shift = 1, drop_remainder = True)

  # The dataset contains a tensor with size of 5.
  dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))

  # Split into two arrays, one for inputs and one for labels.
  dataset = dataset.map(lambda window: (window[ : -1], window[-1 : ]))

  # Shuffle the dataset.
  dataset = dataset.shuffle(shuffle_buffer)

  # Create batches. The 'prefetch' indicates the Tensorflow will
  # fetch the data while working, so we always have data to use.
  dataset = dataset.batch(batch_size).prefetch(1)

  return dataset


# Sequence to sequence dataset.
def seq2seq_window_dataset(series, window_size, batch_size = 32, shuffle_buffer = 1000):
  series = tf.expand_dims(series, axis = -1)
  ds = tf.data.Dataset.from_tensor_slices(series)
  ds = ds.window(window_size + 1, shift = 1, drop_remainder = True)
  ds = ds.flat_map(lambda w: w.batch(window_size + 1))
  ds = ds.shuffle(shuffle_buffer)
  ds = ds.map(lambda w: (w[:-1], w[1:]))
  return ds.batch(batch_size).prefetch(1)


# Predict function.
def model_forecast(model, series, window_size):
  ds = tf.data.Dataset.from_tensor_slices(series)
  ds = ds.window(window_size, shift=1, drop_remainder=True)
  ds = ds.flat_map(lambda w: w.batch(window_size))
  ds = ds.batch(32).prefetch(1)
  forecast = model.predict(ds)
  return forecast

# %%
# Create dataset.
time      = np.arange(4 * 365 + 1)
slope     = 0.05
baseline  = 10
amplitude = 40
series    = baseline + trend(time, slope) + seasonality(time, period = 365, amplitude = amplitude)

noise_level = 5
noise       = white_noise(time, noise_level, seed = 42)

series += noise

plt.figure(figsize=(10, 6))
plot_series(time, series)
plt.show()

# %%
# Prepare for machine learning.
split_time    = 1000
time_train    = time[:split_time]
series_train  = series[:split_time]
time_valid    = time[split_time:]
series_valid  = series[split_time:]

for X_batch, Y_batch in seq2seq_window_dataset(tf.range(10), 3, batch_size = 1):
    print("X: ", X_batch.numpy())
    print("Y: ", Y_batch.numpy())
# Out:
# X:  [[[2]
#   [3]
#   [4]]]
# Y:  [[[3]
#   [4]
#   [5]]]
# X:  [[[5]
#   [6]
#   [7]]]
# Y:  [[[6]
#   [7]
#   [8]]]
# X:  [[[3]
#   [4]
#   [5]]]
# Y:  [[[4]
#   [5]
#   [6]]]
# X:  [[[4]
#   [5]
#   [6]]]
# Y:  [[[5]
#   [6]
#   [7]]]
# X:  [[[0]
#   [1]
#   [2]]]
# Y:  [[[1]
#   [2]
#   [3]]]
# X:  [[[1]
#   [2]
#   [3]]]
# Y:  [[[2]
#   [3]
#   [4]]]
# X:  [[[6]
#   [7]
#   [8]]]
# Y:  [[[7]
#   [8]
#   [9]]]

# %%
# ==================
# RNN Forecasting (Sequence to Sequence)
# ==================
# Clear session, just useful under development, as we usually
# run the session multiple time in the notebook.
SEED        = 42
WINDOW_SIZE = 30
tf.keras.backend.clear_session()
tf.random.set_seed(SEED)
np.random.seed(SEED)

dataset_train = seq2seq_window_dataset(series_train, WINDOW_SIZE, batch_size = 128)

# Build the RNN model.
model = tf.keras.models.Sequential([
  tf.keras.layers.SimpleRNN(100, return_sequences = True, input_shape = [None, 1]),
  tf.keras.layers.SimpleRNN(100, return_sequences = True),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 200.0)
])
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-7 * 10**(epoch / 20)
)
model.compile(
  loss = tf.keras.losses.Huber(),
  optimizer = tf.keras.optimizers.SGD(lr = 1e-7, momentum = 0.9),
  metrics = ["mae"]
)
history = model.fit(dataset_train, epochs = 100, callbacks = [lr_schedule])
# Out:
# Epoch 1/100
# 8/8 [==============================] - 3s 372ms/step - loss: 51.8012 - mae: 53.0833
# Epoch 2/100
# 8/8 [==============================] - 0s 49ms/step - loss: 25.6344 - mae: 25.9857
# Epoch 3/100
# 8/8 [==============================] - 0s 50ms/step - loss: 23.1427 - mae: 23.5584
# Epoch 4/100
# 8/8 [==============================] - 0s 49ms/step - loss: 20.6065 - mae: 21.1993
# Epoch 5/100
# 8/8 [==============================] - 0s 48ms/step - loss: 19.2723 - mae: 19.8319
# Epoch 6/100
# 8/8 [==============================] - 0s 49ms/step - loss: 18.6296 - mae: 19.1122
# Epoch 7/100
# 8/8 [==============================] - 0s 50ms/step - loss: 18.0382 - mae: 18.5297
# Epoch 8/100
# 8/8 [==============================] - 0s 46ms/step - loss: 17.4733 - mae: 18.0482
# Epoch 9/100
# 8/8 [==============================] - 0s 49ms/step - loss: 17.0780 - mae: 17.6386
# Epoch 10/100
# 8/8 [==============================] - 0s 49ms/step - loss: 16.6022 - mae: 17.2318
# Epoch 11/100
# 8/8 [==============================] - 0s 52ms/step - loss: 16.3386 - mae: 16.8067
# Epoch 12/100
# 8/8 [==============================] - 0s 49ms/step - loss: 15.8730 - mae: 16.3507
# Epoch 13/100
# 8/8 [==============================] - 0s 45ms/step - loss: 15.3557 - mae: 15.8836
# Epoch 14/100
# 8/8 [==============================] - 0s 49ms/step - loss: 14.8602 - mae: 15.3958
# Epoch 15/100
# 8/8 [==============================] - 0s 51ms/step - loss: 14.4144 - mae: 14.8776
# Epoch 76/100
# 8/8 [==============================] - 0s 47ms/step - loss: 1137.7245 - mae: 1145.1852
# Epoch 77/100
# 8/8 [==============================] - 0s 53ms/step - loss: 1285.6131 - mae: 1262.8813
# Epoch 78/100
# 8/8 [==============================] - 0s 45ms/step - loss: 1441.8420 - mae: 1426.5850
# Epoch 79/100
# 8/8 [==============================] - 0s 47ms/step - loss: 1609.7367 - mae: 1606.9753
# Epoch 80/100
# 8/8 [==============================] - 0s 50ms/step - loss: 1773.6805 - mae: 1764.6019
# Epoch 81/100
# 8/8 [==============================] - 0s 49ms/step - loss: 2643.0242 - mae: 2481.9136
# Epoch 82/100
# 8/8 [==============================] - 0s 47ms/step - loss: 4019.5434 - mae: 3945.7800
# Epoch 83/100
# 8/8 [==============================] - 0s 45ms/step - loss: 4864.4390 - mae: 4950.0015
# Epoch 84/100
# 8/8 [==============================] - 0s 48ms/step - loss: 5286.0995 - mae: 5374.3828
# Epoch 85/100
# 8/8 [==============================] - 0s 51ms/step - loss: 1493.8321 - mae: 1507.2849
# Epoch 86/100
# 8/8 [==============================] - 0s 50ms/step - loss: 1854.4174 - mae: 1834.2562
# Epoch 87/100
# 8/8 [==============================] - 0s 46ms/step - loss: 2016.5236 - mae: 1978.7997
# Epoch 88/100
# 8/8 [==============================] - 0s 47ms/step - loss: 2305.1195 - mae: 2228.2961
# Epoch 89/100
# 8/8 [==============================] - 0s 50ms/step - loss: 2510.1915 - mae: 2418.3384
# Epoch 90/100
# 8/8 [==============================] - 0s 48ms/step - loss: 2774.4653 - mae: 2689.2917
# Epoch 91/100
# 8/8 [==============================] - 0s 52ms/step - loss: 10691.2006 - mae: 9893.4531
# Epoch 92/100
# 8/8 [==============================] - 0s 50ms/step - loss: 15343.2053 - mae: 15591.6846
# Epoch 93/100
# 8/8 [==============================] - 0s 48ms/step - loss: 14960.4805 - mae: 15248.0244
# Epoch 94/100
# 8/8 [==============================] - 0s 48ms/step - loss: 8832.5277 - mae: 8135.8657
# Epoch 95/100
# 8/8 [==============================] - 0s 49ms/step - loss: 15595.8862 - mae: 16226.2910
# Epoch 96/100
# 8/8 [==============================] - 0s 51ms/step - loss: 12919.3755 - mae: 13395.3174
# Epoch 97/100
# 8/8 [==============================] - 0s 50ms/step - loss: 15760.4998 - mae: 15488.3574
# Epoch 98/100
# 8/8 [==============================] - 0s 49ms/step - loss: 18518.3470 - mae: 17178.2930
# Epoch 99/100
# 8/8 [==============================] - 0s 50ms/step - loss: 31495.7411 - mae: 31628.2148
# Epoch 100/100
# 8/8 [==============================] - 0s 49ms/step - loss: 19904.0614 - mae: 18851.9160

# %%
# Find the optimal learning rate.
plt.semilogx(history.history["lr"], history.history["loss"])
plt.axis([1e-7, 1e-4, 0, 30])
# Out:
# [1e-07, 0.0001, 0, 30]

# %%
# As we see that it would be safe to start with 1e-6.

# %%
# Update model with the learning rate.
tf.keras.backend.clear_session()
tf.random.set_seed(SEED)
np.random.seed(SEED)

dataset_train = seq2seq_window_dataset(series_train, WINDOW_SIZE, batch_size = 128)
dataset_valid = seq2seq_window_dataset(series_valid, WINDOW_SIZE, batch_size = 128)

model = tf.keras.models.Sequential([
  tf.keras.layers.SimpleRNN(100, return_sequences = True, input_shape = [None, 1]),
  tf.keras.layers.SimpleRNN(100, return_sequences = True),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 200.0)
])

model.compile(
  loss = tf.keras.losses.Huber(),
  optimizer = tf.keras.optimizers.SGD(lr = 1e-6, momentum = 0.9),
  metrics = ["mae"]
)

early_stopping = tf.keras.callbacks.EarlyStopping(patience = 10)
model.fit(
  dataset_train,
  epochs = 500,
  validation_data = dataset_valid,
  callbacks = [early_stopping]
)
# Out:
# Epoch 1/500
# 8/8 [==============================] - 2s 236ms/step - loss: 55.8513 - mae: 56.2826 - val_loss: 17.6785 - val_mae: 18.0197
# Epoch 2/500
# 8/8 [==============================] - 1s 65ms/step - loss: 33.9155 - mae: 35.1114 - val_loss: 17.4471 - val_mae: 18.0774
# Epoch 3/500
# 8/8 [==============================] - 1s 67ms/step - loss: 28.3637 - mae: 28.6514 - val_loss: 35.8526 - val_mae: 36.0964
# Epoch 4/500
# 8/8 [==============================] - 1s 63ms/step - loss: 21.0046 - mae: 21.6919 - val_loss: 27.8289 - val_mae: 28.4824
# Epoch 5/500
# 8/8 [==============================] - 1s 64ms/step - loss: 17.9119 - mae: 18.5032 - val_loss: 17.8702 - val_mae: 18.4260
# Epoch 6/500
# 8/8 [==============================] - 1s 63ms/step - loss: 15.3045 - mae: 15.8192 - val_loss: 10.6282 - val_mae: 11.1624
# Epoch 7/500
# 8/8 [==============================] - 1s 63ms/step - loss: 13.8782 - mae: 14.3735 - val_loss: 8.7739 - val_mae: 9.2796
# Epoch 8/500
# 8/8 [==============================] - 1s 66ms/step - loss: 13.0289 - mae: 13.6209 - val_loss: 10.1551 - val_mae: 10.6831
# Epoch 9/500
# 8/8 [==============================] - 1s 65ms/step - loss: 12.5017 - mae: 13.0347 - val_loss: 8.8221 - val_mae: 9.3050
# Epoch 10/500
# 8/8 [==============================] - 1s 69ms/step - loss: 11.7843 - mae: 12.4174 - val_loss: 8.0352 - val_mae: 8.5111
# Epoch 11/500
# 8/8 [==============================] - 1s 63ms/step - loss: 11.4571 - mae: 11.9270 - val_loss: 8.2851 - val_mae: 8.7258
# Epoch 12/500
# 8/8 [==============================] - 1s 68ms/step - loss: 11.0459 - mae: 11.5188 - val_loss: 8.1388 - val_mae: 8.3984
# Epoch 13/500
# 8/8 [==============================] - 1s 65ms/step - loss: 10.6491 - mae: 11.1769 - val_loss: 7.7866 - val_mae: 8.2141
# Epoch 14/500
# 8/8 [==============================] - 1s 66ms/step - loss: 10.3284 - mae: 10.8666 - val_loss: 7.5412 - val_mae: 8.1458
# Epoch 15/500
# 8/8 [==============================] - 0s 62ms/step - loss: 10.1402 - mae: 10.5846 - val_loss: 7.6775 - val_mae: 8.0327
# Epoch 16/500
# 8/8 [==============================] - 1s 68ms/step - loss: 9.9063 - mae: 10.3390 - val_loss: 7.5106 - val_mae: 7.9152
# Epoch 17/500
500
# 8/8 [==============================] - 1s 64ms/step - loss: 5.9969 - mae: 6.5110 - val_loss: 5.4278 - val_mae: 5.9063
# Epoch 78/500
# 8/8 [==============================] - 1s 66ms/step - loss: 5.9884 - mae: 6.4934 - val_loss: 5.4444 - val_mae: 5.9220
# Epoch 79/500
# 8/8 [==============================] - 0s 61ms/step - loss: 6.0331 - mae: 6.4777 - val_loss: 5.5304 - val_mae: 5.9543
# Epoch 80/500
# 8/8 [==============================] - 1s 63ms/step - loss: 6.0132 - mae: 6.4638 - val_loss: 5.4521 - val_mae: 5.8958
# Epoch 81/500
# 8/8 [==============================] - 1s 63ms/step - loss: 5.9766 - mae: 6.4498 - val_loss: 5.4561 - val_mae: 6.0023
# Epoch 82/500
# 8/8 [==============================] - 0s 60ms/step - loss: 5.9501 - mae: 6.4333 - val_loss: 5.4370 - val_mae: 5.9098
# Epoch 83/500
# 8/8 [==============================] - 0s 62ms/step - loss: 5.9354 - mae: 6.4228 - val_loss: 5.4446 - val_mae: 5.8844
# Epoch 84/500
# 8/8 [==============================] - 0s 59ms/step - loss: 5.9300 - mae: 6.4064 - val_loss: 5.3865 - val_mae: 5.8665
# Epoch 85/500
# 8/8 [==============================] - 0s 62ms/step - loss: 5.8836 - mae: 6.3913 - val_loss: 5.3660 - val_mae: 5.8635
# Epoch 86/500
# 8/8 [==============================] - 1s 63ms/step - loss: 5.9013 - mae: 6.3781 - val_loss: 5.3698 - val_mae: 5.8302
# Epoch 87/500
# 8/8 [==============================] - 0s 60ms/step - loss: 5.8897 - mae: 6.3675 - val_loss: 5.5144 - val_mae: 6.0156
# Epoch 88/500
# 8/8 [==============================] - 0s 60ms/step - loss: 5.8720 - mae: 6.3616 - val_loss: 5.2486 - val_mae: 5.7688
# Epoch 89/500
# 8/8 [==============================] - 1s 63ms/step - loss: 5.8497 - mae: 6.3500 - val_loss: 5.5552 - val_mae: 6.0661
# Epoch 90/500
# 8/8 [==============================] - 0s 59ms/step - loss: 5.8939 - mae: 6.3488 - val_loss: 5.2505 - val_mae: 5.7532
# Epoch 91/500
# 8/8 [==============================] - 0s 60ms/step - loss: 5.8791 - mae: 6.3332 - val_loss: 5.4019 - val_mae: 5.8869
# Epoch 92/500
# 8/8 [==============================] - 0s 58ms/step - loss: 5.8247 - mae: 6.3067 - val_loss: 5.2891 - val_mae: 5.7609
# Epoch 93/500
# 8/8 [==============================] - 0s 61ms/step - loss: 5.8213 - mae: 6.2929 - val_loss: 5.4045 - val_mae: 5.9055
# Epoch 94/500
# 8/8 [==============================] - 1s 74ms/step - loss: 5.7827 - mae: 6.2763 - val_loss: 5.2437 - val_mae: 5.7578
# Epoch 95/500
# 8/8 [==============================] - 1s 64ms/step - loss: 5.7753 - mae: 6.2654 - val_loss: 5.3492 - val_mae: 5.8862
# Epoch 96/500
# 8/8 [==============================] - 1s 65ms/step - loss: 5.7687 - mae: 6.2523 - val_loss: 5.3568 - val_mae: 5.8154
# Epoch 97/500
# 8/8 [==============================] - 0s 62ms/step - loss: 5.7431 - mae: 6.2397 - val_loss: 5.4340 - val_mae: 5.9087
# Epoch 98/500
# 8/8 [==============================] - 0s 60ms/step - loss: 5.7477 - mae: 6.2446 - val_loss: 5.2697 - val_mae: 5.6961
# Epoch 99/500
# 8/8 [==============================] - 1s 65ms/step - loss: 5.7334 - mae: 6.2160 - val_loss: 5.3113 - val_mae: 5.7947
# Epoch 100/500
# 8/8 [==============================] - 1s 65ms/step - loss: 5.7162 - mae: 6.2106 - val_loss: 5.2733 - val_mae: 5.7683
# Epoch 101/500
# 8/8 [==============================] - 1s 63ms/step - loss: 5.6890 - mae: 6.1936 - val_loss: 5.2871 - val_mae: 5.7706
# Epoch 102/500
# 8/8 [==============================] - 1s 63ms/step - loss: 5.6865 - mae: 6.1796 - val_loss: 5.3931 - val_mae: 5.8152
# Epoch 103/500
# 8/8 [==============================] - 1s 63ms/step - loss: 5.6580 - mae: 6.1663 - val_loss: 5.2540 - val_mae: 5.7745
# Epoch 104/500
# 8/8 [==============================] - 1s 74ms/step - loss: 5.6964 - mae: 6.1536 - val_loss: 5.2199 - val_mae: 5.7325
# Epoch 105/500
# 8/8 [==============================] - 1s 65ms/step - loss: 5.7060 - mae: 6.1403 - val_loss: 5.2741 - val_mae: 5.8110
# Epoch 106/500
# 8/8 [==============================] - 1s 65ms/step - loss: 5.6725 - mae: 6.1271 - val_loss: 5.2017 - val_mae: 5.6685
# Epoch 107/500
# 8/8 [==============================] - 0s 61ms/step - loss: 5.6408 - mae: 6.1214 - val_loss: 5.3760 - val_mae: 5.8138
# Epoch 108/500
# 8/8 [==============================] - 1s 75ms/step - loss: 5.6541 - mae: 6.1075 - val_loss: 5.3060 - val_mae: 5.7576
# Epoch 109/500
# 8/8 [==============================] - 1s 69ms/step - loss: 5.6133 - mae: 6.0943 - val_loss: 5.2524 - val_mae: 5.7214
# Epoch 110/500
# 8/8 [==============================] - 1s 68ms/step - loss: 5.5984 - mae: 6.0801 - val_loss: 5.1861 - val_mae: 5.6820
# Epoch 111/500
# 8/8 [==============================] - 1s 67ms/step - loss: 5.6278 - mae: 6.0738 - val_loss: 5.3553 - val_mae: 5.8282
# Epoch 112/500
# 8/8 [==============================] - 1s 64ms/step - loss: 5.6185 - mae: 6.0598 - val_loss: 5.1867 - val_mae: 5.6513
# Epoch 113/500
# 8/8 [==============================] - 1s 63ms/step - loss: 5.5832 - mae: 6.0503 - val_loss: 5.3155 - val_mae: 5.7741
# Epoch 114/500
# 8/8 [==============================] - 1s 64ms/step - loss: 5.5659 - mae: 6.0355 - val_loss: 5.2853 - val_mae: 5.7452
# Epoch 115/500
# 8/8 [==============================] - 1s 70ms/step - loss: 5.5550 - mae: 6.0242 - val_loss: 5.2186 - val_mae: 5.6990
# Epoch 116/500
# 8/8 [==============================] - 1s 67ms/step - loss: 5.5115 - mae: 6.0123 - val_loss: 5.1687 - val_mae: 5.6880
# Epoch 117/500
# 8/8 [==============================] - 1s 69ms/step - loss: 5.5226 - mae: 6.0023 - val_loss: 5.1601 - val_mae: 5.6806
# Epoch 118/500
# 8/8 [==============================] - 0s 62ms/step - loss: 5.5183 - mae: 5.9966 - val_loss: 5.3029 - val_mae: 5.7425
# Epoch 119/500
# 8/8 [==============================] - 1s 63ms/step - loss: 5.5245 - mae: 5.9848 - val_loss: 5.2220 - val_mae: 5.6341
# Epoch 120/500
# 8/8 [==============================] - 0s 60ms/step - loss: 5.4806 - mae: 5.9793 - val_loss: 5.2878 - val_mae: 5.7136
# Epoch 121/500
# 8/8 [==============================] - 0s 58ms/step - loss: 5.4825 - mae: 5.9698 - val_loss: 5.2148 - val_mae: 5.7092
# Epoch 122/500
# 8/8 [==============================] - 1s 64ms/step - loss: 5.4931 - mae: 5.9603 - val_loss: 5.1480 - val_mae: 5.6836
# Epoch 123/500
# 8/8 [==============================] - 0s 60ms/step - loss: 5.4699 - mae: 5.9427 - val_loss: 5.1792 - val_mae: 5.7103
# Epoch 124/500
# 8/8 [==============================] - 1s 63ms/step - loss: 5.4665 - mae: 5.9309 - val_loss: 5.1589 - val_mae: 5.6396
# Epoch 125/500
# 8/8 [==============================] - 1s 64ms/step - loss: 5.4465 - mae: 5.9188 - val_loss: 5.2403 - val_mae: 5.7024
# Epoch 126/500
# 8/8 [==============================] - 0s 61ms/step - loss: 5.4472 - mae: 5.9083 - val_loss: 5.1686 - val_mae: 5.6640
# Epoch 127/500
# 8/8 [==============================] - 1s 72ms/step - loss: 5.4259 - mae: 5.8979 - val_loss: 5.1556 - val_mae: 5.6217
# Epoch 128/500
# 8/8 [==============================] - 1s 72ms/step - loss: 5.3968 - mae: 5.8928 - val_loss: 5.2615 - val_mae: 5.7583
# Epoch 129/500
# 8/8 [==============================] - 1s 70ms/step - loss: 5.4104 - mae: 5.8810 - val_loss: 5.1096 - val_mae: 5.6117
# Epoch 130/500
# 8/8 [==============================] - 1s 64ms/step - loss: 5.3607 - mae: 5.8681 - val_loss: 5.2225 - val_mae: 5.6829
# Epoch 131/500
# 8/8 [==============================] - 1s 67ms/step - loss: 5.3659 - mae: 5.8576 - val_loss: 5.1866 - val_mae: 5.6872
# Epoch 132/500
# 8/8 [==============================] - 1s 66ms/step - loss: 5.3826 - mae: 5.8496 - val_loss: 5.1490 - val_mae: 5.6465
# Epoch 133/500
# 8/8 [==============================] - 0s 59ms/step - loss: 5.3794 - mae: 5.8393 - val_loss: 5.1083 - val_mae: 5.5950
# Epoch 134/500
# 8/8 [==============================] - 1s 64ms/step - loss: 5.3521 - mae: 5.8293 - val_loss: 5.1538 - val_mae: 5.6376
# Epoch 135/500
# 8/8 [==============================] - 0s 62ms/step - loss: 5.3285 - mae: 5.8225 - val_loss: 5.1202 - val_mae: 5.6016
# Epoch 136/500
# 8/8 [==============================] - 0s 62ms/step - loss: 5.3966 - mae: 5.8189 - val_loss: 5.2983 - val_mae: 5.8202
# Epoch 137/500
# 8/8 [==============================] - 0s 58ms/step - loss: 5.3461 - mae: 5.8101 - val_loss: 5.0645 - val_mae: 5.6001
# Epoch 138/500
# 8/8 [==============================] - 1s 63ms/step - loss: 5.3074 - mae: 5.7983 - val_loss: 5.2570 - val_mae: 5.7213
# Epoch 139/500
# 8/8 [==============================] - 0s 60ms/step - loss: 5.3062 - mae: 5.7869 - val_loss: 5.1197 - val_mae: 5.5661
# Epoch 140/500
# 8/8 [==============================] - 0s 59ms/step - loss: 5.2997 - mae: 5.7787 - val_loss: 5.2172 - val_mae: 5.7301
# Epoch 141/500
# 8/8 [==============================] - 1s 66ms/step - loss: 5.3017 - mae: 5.7710 - val_loss: 5.1280 - val_mae: 5.5731
# Epoch 142/500
# 8/8 [==============================] - 0s 61ms/step - loss: 5.2892 - mae: 5.7563 - val_loss: 5.1824 - val_mae: 5.6691
# Epoch 143/500
# 8/8 [==============================] - 0s 62ms/step - loss: 5.2684 - mae: 5.7453 - val_loss: 5.1202 - val_mae: 5.6114
# Epoch 144/500
# 8/8 [==============================] - 1s 64ms/step - loss: 5.2645 - mae: 5.7374 - val_loss: 5.1674 - val_mae: 5.6156
# Epoch 145/500
# 8/8 [==============================] - 0s 59ms/step - loss: 5.2304 - mae: 5.7297 - val_loss: 5.0300 - val_mae: 5.5416
# Epoch 146/500
# 8/8 [==============================] - 0s 62ms/step - loss: 5.2302 - mae: 5.7209 - val_loss: 5.1571 - val_mae: 5.5954
# Epoch 147/500
# 8/8 [==============================] - 1s 64ms/step - loss: 5.2465 - mae: 5.7138 - val_loss: 5.2335 - val_mae: 5.7155
# Epoch 148/500
# 8/8 [==============================] - 0s 61ms/step - loss: 5.2463 - mae: 5.7112 - val_loss: 5.0695 - val_mae: 5.4999
# Epoch 149/500
# 8/8 [==============================] - 1s 65ms/step - loss: 5.2406 - mae: 5.7046 - val_loss: 5.3396 - val_mae: 5.8294
# Epoch 150/500
# 8/8 [==============================] - 1s 73ms/step - loss: 5.2339 - mae: 5.6968 - val_loss: 5.0290 - val_mae: 5.5237
# Epoch 151/500
# 8/8 [==============================] - 1s 64ms/step - loss: 5.2091 - mae: 5.6773 - val_loss: 5.0745 - val_mae: 5.5445
# Epoch 152/500
# 8/8 [==============================] - 1s 65ms/step - loss: 5.1796 - mae: 5.6707 - val_loss: 5.1758 - val_mae: 5.6299
# Epoch 153/500
# 8/8 [==============================] - 1s 70ms/step - loss: 5.1676 - mae: 5.6612 - val_loss: 5.0825 - val_mae: 5.5453
# Epoch 154/500
# 8/8 [==============================] - 1s 66ms/step - loss: 5.1963 - mae: 5.6528 - val_loss: 5.2104 - val_mae: 5.6627
# Epoch 155/500
# 8/8 [==============================] - 1s 64ms/step - loss: 5.1919 - mae: 5.6493 - val_loss: 5.0479 - val_mae: 5.5102
# Epoch 156/500
# 8/8 [==============================] - 1s 70ms/step - loss: 5.1769 - mae: 5.6419 - val_loss: 5.1549 - val_mae: 5.6269
# Epoch 157/500
# 8/8 [==============================] - 1s 65ms/step - loss: 5.1762 - mae: 5.6378 - val_loss: 4.9962 - val_mae: 5.4931
# Epoch 158/500
# 8/8 [==============================] - 1s 65ms/step - loss: 5.1468 - mae: 5.6330 - val_loss: 5.1921 - val_mae: 5.6579
# Epoch 159/500
# 8/8 [==============================] - 1s 66ms/step - loss: 5.1325 - mae: 5.6222 - val_loss: 5.0146 - val_mae: 5.5161
# Epoch 160/500
# 8/8 [==============================] - 1s 65ms/step - loss: 5.1332 - mae: 5.6056 - val_loss: 5.1307 - val_mae: 5.5564
# Epoch 161/500
# 8/8 [==============================] - 1s 67ms/step - loss: 5.1288 - mae: 5.6010 - val_loss: 5.1063 - val_mae: 5.5699
# Epoch 162/500
# 8/8 [==============================] - 1s 71ms/step - loss: 5.1359 - mae: 5.5961 - val_loss: 5.0385 - val_mae: 5.4942
# Epoch 163/500
# 8/8 [==============================] - 1s 69ms/step - loss: 5.1085 - mae: 5.5883 - val_loss: 5.0393 - val_mae: 5.5616
# Epoch 164/500
# 8/8 [==============================] - 1s 68ms/step - loss: 5.1003 - mae: 5.5745 - val_loss: 5.0195 - val_mae: 5.4990
# Epoch 165/500
# 8/8 [==============================] - 1s 67ms/step - loss: 5.0987 - mae: 5.5682 - val_loss: 5.0871 - val_mae: 5.5647
# Epoch 166/500
# 8/8 [==============================] - 1s 69ms/step - loss: 5.0794 - mae: 5.5650 - val_loss: 5.0717 - val_mae: 5.5398
# Epoch 167/500
# 8/8 [==============================] - 1s 65ms/step - loss: 5.0839 - mae: 5.5591 - val_loss: 5.1230 - val_mae: 5.5197

# %%
# Forcast the model.
rnn_forecast = model_forecast(
    model,
    series[..., np.newaxis],
    WINDOW_SIZE
)
rnn_forecast = rnn_forecast[split_time - WINDOW_SIZE:-1, -1, 0]

# %%
# Plot the forecast.
plt.figure(figsize = (10, 6))
plot_series(time_valid, series_valid)
plot_series(time_valid, rnn_forecast)

mae = tf.keras.metrics.mean_absolute_error(series_valid, rnn_forecast).numpy()
print("MAE:", mae)
# Out:
# MAE: 5.1336274
