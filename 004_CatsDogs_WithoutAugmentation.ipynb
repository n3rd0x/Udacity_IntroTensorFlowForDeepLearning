# %%
# Education - Udacity "Intro to TensorFlow for Deep Learning"
# Ref: https://colab.research.google.com/github/tensorflow/examples/blob/master/courses/udacity_intro_to_tensorflow_for_deep_learning/l05c01_dogs_vs_cats_without_augmentation.ipynb

# %%
# Import packages.
from __future__ import absolute_import, division, print_function, unicode_literals
try:
  # Use the %tensorflow_version magic if in colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
import matplotlib.pyplot as plt
import numpy as np
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)
# Out:
# TensorFlow 2.x selected.

# %%
# Download dataset.
_URL = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip'
zip_dir = tf.keras.utils.get_file('cats_and_dogs_filterted.zip', origin=_URL, extract=True)
# Out:
# Downloading data from https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# 68608000/68606236 [==============================] - 1s 0us/step

# %%
# List directories.
zip_dir_base = os.path.dirname(zip_dir)
# !find $zip_dir_base -type d -print

# Save working variables.
base_dir = os.path.join(os.path.dirname(zip_dir), 'cats_and_dogs_filtered')
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

train_cats_dir = os.path.join(train_dir, 'cats')  # directory with our training cat pictures
train_dogs_dir = os.path.join(train_dir, 'dogs')  # directory with our training dog pictures
validation_cats_dir = os.path.join(validation_dir, 'cats')  # directory with our validation cat pictures
validation_dogs_dir = os.path.join(validation_dir, 'dogs')  # directory with our validation dog pictures
# Out:
# /root/.keras/datasets
# /root/.keras/datasets/cats_and_dogs_filtered
# /root/.keras/datasets/cats_and_dogs_filtered/validation
# /root/.keras/datasets/cats_and_dogs_filtered/validation/dogs
# /root/.keras/datasets/cats_and_dogs_filtered/validation/cats
# /root/.keras/datasets/cats_and_dogs_filtered/train
# /root/.keras/datasets/cats_and_dogs_filtered/train/dogs
# /root/.keras/datasets/cats_and_dogs_filtered/train/cats

# %%
# List data.
num_cats_tr = len(os.listdir(train_cats_dir))
num_dogs_tr = len(os.listdir(train_dogs_dir))

num_cats_val = len(os.listdir(validation_cats_dir))
num_dogs_val = len(os.listdir(validation_dogs_dir))

total_train = num_cats_tr + num_dogs_tr
total_val = num_cats_val + num_dogs_val

print('total training cat images:', num_cats_tr)
print('total training dog images:', num_dogs_tr)

print('total validation cat images:', num_cats_val)
print('total validation dog images:', num_dogs_val)
print("--")
print("Total training images:", total_train)
print("Total validation images:", total_val)
# Out:
# total training cat images: 1000
# total training dog images: 1000
# total validation cat images: 500
# total validation dog images: 500
# --
# Total training images: 2000
# Total validation images: 1000

# %%
BATCH_SIZE = 100  # Number of training examples to process before updating our models variables
IMG_SHAPE  = 150  # Our training data consists of images with width of 150 pixels and height of 150 pixels

# %%
'''
Images must be formatted into appropriately pre-processed floating point tensors before being fed into the network.
The steps involved in preparing these images are:

Read images from the disk
Decode contents of these images and convert it into proper grid format as per their RGB content
Convert them into floating point tensors
Rescale the tensors from values between 0 and 255 to values between 0 and 1, as neural networks prefer to
deal with small input values. Fortunately, all these tasks can be done using
the class tf.keras.preprocessing.image.ImageDataGenerator.
'''
# Rescale the value [0, 1].
train_image_generator      = ImageDataGenerator(rescale=1./255)  # Generator for our training data
validation_image_generator = ImageDataGenerator(rescale=1./255)  # Generator for our validation data

# We use the 'binary' mode because we have only two classes.
train_data_gen = train_image_generator.flow_from_directory(batch_size=BATCH_SIZE,
                                                           directory=train_dir,
                                                           shuffle=True,
                                                           target_size=(IMG_SHAPE,IMG_SHAPE), #(150,150)
                                                           class_mode='binary')

val_data_gen = validation_image_generator.flow_from_directory(batch_size=BATCH_SIZE,
                                                              directory=validation_dir,
                                                              shuffle=False,
                                                              target_size=(IMG_SHAPE,IMG_SHAPE), #(150,150)
                                                              class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %%
# Visualize the data.
# The next function returns a batch from the dataset.
# One batch is a tuple of (many images, many labels).
# For right now, we're discarding the labels because we just want to look at the images.
sample_training_images, _ = next(train_data_gen)

# %%
# This function will plot images in the form of a grid with 1 row and 5 columns where images are placed in each column.
def plotImages(images_arr):
    fig, axes = plt.subplots(1, 5, figsize=(20,20))
    axes = axes.flatten()
    for img, ax in zip(images_arr, axes):
        ax.imshow(img)
    plt.tight_layout()
    plt.show()

# %%
# Plot images 0 - 4
plotImages(sample_training_images[:5])

# %%
# Build the model.
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(2, activation='softmax')
])

# %%
# Compile the model.
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# Print summary.
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 128)       147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               3211776
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 3,453,634
# Trainable params: 3,453,634
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model.
EPOCHS = 100
history = model.fit_generator(
    train_data_gen,
    steps_per_epoch=int(np.ceil(total_train / float(BATCH_SIZE))),
    epochs=EPOCHS,
    validation_data=val_data_gen,
    validation_steps=int(np.ceil(total_val / float(BATCH_SIZE)))
)
# Out:
# Train for 20 steps, validate for 10 steps
# Epoch 1/100
# 20/20 [==============================] - 14s 687ms/step - loss: 0.7150 - accuracy: 0.5120 - val_loss: 0.6926 - val_accuracy: 0.5110
# Epoch 2/100
# 20/20 [==============================] - 8s 391ms/step - loss: 0.6918 - accuracy: 0.5325 - val_loss: 0.6848 - val_accuracy: 0.6180
# Epoch 3/100
# 20/20 [==============================] - 8s 378ms/step - loss: 0.6818 - accuracy: 0.5655 - val_loss: 0.6599 - val_accuracy: 0.6100
# Epoch 4/100
# 20/20 [==============================] - 8s 384ms/step - loss: 0.6661 - accuracy: 0.5845 - val_loss: 0.6419 - val_accuracy: 0.6250
# Epoch 5/100
# 20/20 [==============================] - 8s 384ms/step - loss: 0.6322 - accuracy: 0.6240 - val_loss: 0.6145 - val_accuracy: 0.6600
# Epoch 6/100
# 20/20 [==============================] - 8s 381ms/step - loss: 0.6052 - accuracy: 0.6615 - val_loss: 0.6473 - val_accuracy: 0.5770
# Epoch 7/100
# 20/20 [==============================] - 8s 382ms/step - loss: 0.6061 - accuracy: 0.6870 - val_loss: 0.6126 - val_accuracy: 0.6830
# Epoch 8/100
# 20/20 [==============================] - 8s 380ms/step - loss: 0.5470 - accuracy: 0.7240 - val_loss: 0.5636 - val_accuracy: 0.7170
# Epoch 9/100
# 20/20 [==============================] - 8s 385ms/step - loss: 0.5073 - accuracy: 0.7485 - val_loss: 0.5582 - val_accuracy: 0.7210
# Epoch 10/100
# 20/20 [==============================] - 8s 384ms/step - loss: 0.4641 - accuracy: 0.7860 - val_loss: 0.5646 - val_accuracy: 0.7170
# Epoch 11/100
# 20/20 [==============================] - 8s 384ms/step - loss: 0.4405 - accuracy: 0.8080 - val_loss: 0.5535 - val_accuracy: 0.7160
# Epoch 12/100
# 20/20 [==============================] - 8s 379ms/step - loss: 0.4077 - accuracy: 0.8130 - val_loss: 0.5550 - val_accuracy: 0.7450
# Epoch 13/100
# 20/20 [==============================] - 8s 382ms/step - loss: 0.3420 - accuracy: 0.8535 - val_loss: 0.5679 - val_accuracy: 0.7400
# Epoch 14/100
# 20/20 [==============================] - 8s 382ms/step - loss: 0.2763 - accuracy: 0.8805 - val_loss: 0.6260 - val_accuracy: 0.7300
# Epoch 15/100
# 20/20 [==============================] - 8s 376ms/step - loss: 0.2464 - accuracy: 0.9030 - val_loss: 0.6134 - val_accuracy: 0.7390
# Epoch 16/100
# 20/20 [==============================] - 8s 380ms/step - loss: 0.1996 - accuracy: 0.9175 - val_loss: 0.6796 - val_accuracy: 0.7360
# Epoch 17/100
# 20/20 [==============================] - 8s 379ms/step - loss: 0.1492 - accuracy: 0.9440 - val_loss: 0.7359 - val_accuracy: 0.7430
# Epoch 18/100
# 20/20 [==============================] - 8s 377ms/step - loss: 0.1088 - accuracy: 0.9610 - val_loss: 0.8467 - val_accuracy: 0.7550
# Epoch 19/100
# 20/20 [==============================] - 8s 376ms/step - loss: 0.0961 - accuracy: 0.9650 - val_loss: 0.9319 - val_accuracy: 0.7140
# Epoch 20/100
# 20/20 [==============================] - 7s 373ms/step - loss: 0.1133 - accuracy: 0.9580 - val_loss: 0.8883 - val_accuracy: 0.7380
# Epoch 21/100
# 20/20 [==============================] - 8s 379ms/step - loss: 0.0438 - accuracy: 0.9870 - val_loss: 1.0231 - val_accuracy: 0.7540
# Epoch 22/100
# 20/20 [==============================] - 8s 376ms/step - loss: 0.0174 - accuracy: 0.9975 - val_loss: 1.2476 - val_accuracy: 0.7560
# Epoch 23/100
# 20/20 [==============================] - 7s 375ms/step - loss: 0.0135 - accuracy: 0.9980 - val_loss: 1.3478 - val_accuracy: 0.7570
# Epoch 24/100
# 20/20 [==============================] - 8s 375ms/step - loss: 0.0093 - accuracy: 0.9990 - val_loss: 1.4929 - val_accuracy: 0.7590
# Epoch 25/100
# 20/20 [==============================] - 7s 369ms/step - loss: 0.0053 - accuracy: 0.9995 - val_loss: 1.4778 - val_accuracy: 0.7430
# Epoch 26/100
# 20/20 [==============================] - 7s 366ms/step - loss: 0.0136 - accuracy: 0.9970 - val_loss: 1.3554 - val_accuracy: 0.7600
# Epoch 27/100
# 20/20 [==============================] - 7s 364ms/step - loss: 0.0096 - accuracy: 0.9975 - val_loss: 1.4245 - val_accuracy: 0.7690
# Epoch 28/100
# 20/20 [==============================] - 7s 366ms/step - loss: 0.0189 - accuracy: 0.9940 - val_loss: 1.5026 - val_accuracy: 0.7470
# Epoch 29/100
# 20/20 [==============================] - 7s 368ms/step - loss: 0.0350 - accuracy: 0.9885 - val_loss: 1.3843 - val_accuracy: 0.7410
# Epoch 30/100
# 20/20 [==============================] - 7s 370ms/step - loss: 0.0250 - accuracy: 0.9910 - val_loss: 1.4625 - val_accuracy: 0.7400
# Epoch 31/100
# 20/20 [==============================] - 7s 366ms/step - loss: 0.0162 - accuracy: 0.9945 - val_loss: 1.5061 - val_accuracy: 0.7440
# Epoch 32/100
# 20/20 [==============================] - 7s 371ms/step - loss: 0.0139 - accuracy: 0.9960 - val_loss: 1.5890 - val_accuracy: 0.7380
# Epoch 33/100
# 20/20 [==============================] - 7s 369ms/step - loss: 0.0074 - accuracy: 0.9970 - val_loss: 1.5870 - val_accuracy: 0.7490
# Epoch 34/100
# 20/20 [==============================] - 7s 367ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.6024 - val_accuracy: 0.7590
# Epoch 35/100
# 20/20 [==============================] - 7s 366ms/step - loss: 6.8796e-04 - accuracy: 1.0000 - val_loss: 1.6840 - val_accuracy: 0.7580
# Epoch 36/100
# 20/20 [==============================] - 7s 366ms/step - loss: 2.9136e-04 - accuracy: 1.0000 - val_loss: 1.7253 - val_accuracy: 0.7590
# Epoch 37/100
# 20/20 [==============================] - 7s 370ms/step - loss: 2.1084e-04 - accuracy: 1.0000 - val_loss: 1.7548 - val_accuracy: 0.7600
# Epoch 38/100
# 20/20 [==============================] - 7s 373ms/step - loss: 1.7585e-04 - accuracy: 1.0000 - val_loss: 1.7804 - val_accuracy: 0.7610
# Epoch 39/100
# 20/20 [==============================] - 7s 369ms/step - loss: 1.5073e-04 - accuracy: 1.0000 - val_loss: 1.7995 - val_accuracy: 0.7620
# Epoch 40/100
# 20/20 [==============================] - 7s 375ms/step - loss: 1.3388e-04 - accuracy: 1.0000 - val_loss: 1.8153 - val_accuracy: 0.7600
# Epoch 41/100
# 20/20 [==============================] - 8s 375ms/step - loss: 1.2036e-04 - accuracy: 1.0000 - val_loss: 1.8339 - val_accuracy: 0.7610
# Epoch 42/100
# 20/20 [==============================] - 7s 371ms/step - loss: 1.0977e-04 - accuracy: 1.0000 - val_loss: 1.8482 - val_accuracy: 0.7600
# Epoch 43/100
# 20/20 [==============================] - 7s 373ms/step - loss: 1.0105e-04 - accuracy: 1.0000 - val_loss: 1.8615 - val_accuracy: 0.7610
# Epoch 44/100
# 20/20 [==============================] - 7s 370ms/step - loss: 9.2726e-05 - accuracy: 1.0000 - val_loss: 1.8760 - val_accuracy: 0.7600
# Epoch 45/100
# 20/20 [==============================] - 7s 371ms/step - loss: 8.6408e-05 - accuracy: 1.0000 - val_loss: 1.8875 - val_accuracy: 0.7610
# Epoch 46/100
# 20/20 [==============================] - 7s 370ms/step - loss: 8.0457e-05 - accuracy: 1.0000 - val_loss: 1.8989 - val_accuracy: 0.7610
# Epoch 47/100
# 20/20 [==============================] - 7s 373ms/step - loss: 7.5022e-05 - accuracy: 1.0000 - val_loss: 1.9096 - val_accuracy: 0.7600
# Epoch 48/100
# 20/20 [==============================] - 7s 373ms/step - loss: 7.0473e-05 - accuracy: 1.0000 - val_loss: 1.9211 - val_accuracy: 0.7610
# Epoch 49/100
# 20/20 [==============================] - 7s 373ms/step - loss: 6.6187e-05 - accuracy: 1.0000 - val_loss: 1.9321 - val_accuracy: 0.7600
# Epoch 50/100
# 20/20 [==============================] - 7s 372ms/step - loss: 6.2541e-05 - accuracy: 1.0000 - val_loss: 1.9402 - val_accuracy: 0.7610
# Epoch 51/100
# 20/20 [==============================] - 7s 373ms/step - loss: 5.8986e-05 - accuracy: 1.0000 - val_loss: 1.9505 - val_accuracy: 0.7600
# Epoch 52/100
# 20/20 [==============================] - 7s 373ms/step - loss: 5.5838e-05 - accuracy: 1.0000 - val_loss: 1.9592 - val_accuracy: 0.7600
# Epoch 53/100
# 20/20 [==============================] - 8s 375ms/step - loss: 5.3160e-05 - accuracy: 1.0000 - val_loss: 1.9669 - val_accuracy: 0.7590
# Epoch 54/100
# 20/20 [==============================] - 7s 375ms/step - loss: 5.0643e-05 - accuracy: 1.0000 - val_loss: 1.9769 - val_accuracy: 0.7590
# Epoch 55/100
# 20/20 [==============================] - 8s 377ms/step - loss: 4.8003e-05 - accuracy: 1.0000 - val_loss: 1.9842 - val_accuracy: 0.7600
# Epoch 56/100
# 20/20 [==============================] - 7s 373ms/step - loss: 4.5907e-05 - accuracy: 1.0000 - val_loss: 1.9911 - val_accuracy: 0.7600
# Epoch 57/100
# 20/20 [==============================] - 7s 373ms/step - loss: 4.3723e-05 - accuracy: 1.0000 - val_loss: 1.9994 - val_accuracy: 0.7610
# Epoch 58/100
# 20/20 [==============================] - 7s 373ms/step - loss: 4.1816e-05 - accuracy: 1.0000 - val_loss: 2.0067 - val_accuracy: 0.7600
# Epoch 59/100
# 20/20 [==============================] - 7s 372ms/step - loss: 4.0057e-05 - accuracy: 1.0000 - val_loss: 2.0151 - val_accuracy: 0.7600
# Epoch 60/100
# 20/20 [==============================] - 7s 372ms/step - loss: 3.8332e-05 - accuracy: 1.0000 - val_loss: 2.0215 - val_accuracy: 0.7600
# Epoch 61/100
# 20/20 [==============================] - 7s 372ms/step - loss: 3.6828e-05 - accuracy: 1.0000 - val_loss: 2.0278 - val_accuracy: 0.7600
# Epoch 62/100
# 20/20 [==============================] - 7s 373ms/step - loss: 3.5324e-05 - accuracy: 1.0000 - val_loss: 2.0355 - val_accuracy: 0.7600
# Epoch 63/100
# 20/20 [==============================] - 7s 370ms/step - loss: 3.3953e-05 - accuracy: 1.0000 - val_loss: 2.0425 - val_accuracy: 0.7600
# Epoch 64/100
# 20/20 [==============================] - 7s 371ms/step - loss: 3.2713e-05 - accuracy: 1.0000 - val_loss: 2.0487 - val_accuracy: 0.7600
# Epoch 65/100
# 20/20 [==============================] - 8s 377ms/step - loss: 3.1726e-05 - accuracy: 1.0000 - val_loss: 2.0538 - val_accuracy: 0.7600
# Epoch 66/100
# 20/20 [==============================] - 7s 371ms/step - loss: 3.0452e-05 - accuracy: 1.0000 - val_loss: 2.0629 - val_accuracy: 0.7600
# Epoch 67/100
# 20/20 [==============================] - 7s 371ms/step - loss: 2.9306e-05 - accuracy: 1.0000 - val_loss: 2.0674 - val_accuracy: 0.7600
# Epoch 68/100
# 20/20 [==============================] - 7s 366ms/step - loss: 2.8312e-05 - accuracy: 1.0000 - val_loss: 2.0730 - val_accuracy: 0.7610
# Epoch 69/100
# 20/20 [==============================] - 7s 370ms/step - loss: 2.7365e-05 - accuracy: 1.0000 - val_loss: 2.0796 - val_accuracy: 0.7610
# Epoch 70/100
# 20/20 [==============================] - 7s 368ms/step - loss: 2.6375e-05 - accuracy: 1.0000 - val_loss: 2.0855 - val_accuracy: 0.7610
# Epoch 71/100
# 20/20 [==============================] - 7s 369ms/step - loss: 2.5525e-05 - accuracy: 1.0000 - val_loss: 2.0909 - val_accuracy: 0.7600
# Epoch 72/100
# 20/20 [==============================] - 7s 367ms/step - loss: 2.4746e-05 - accuracy: 1.0000 - val_loss: 2.0957 - val_accuracy: 0.7600
# Epoch 73/100
# 20/20 [==============================] - 7s 373ms/step - loss: 2.3894e-05 - accuracy: 1.0000 - val_loss: 2.1026 - val_accuracy: 0.7600
# Epoch 74/100
# 20/20 [==============================] - 7s 372ms/step - loss: 2.3145e-05 - accuracy: 1.0000 - val_loss: 2.1079 - val_accuracy: 0.7600
# Epoch 75/100
# 20/20 [==============================] - 7s 374ms/step - loss: 2.2453e-05 - accuracy: 1.0000 - val_loss: 2.1137 - val_accuracy: 0.7600
# Epoch 76/100
# 20/20 [==============================] - 7s 373ms/step - loss: 2.1777e-05 - accuracy: 1.0000 - val_loss: 2.1179 - val_accuracy: 0.7590
# Epoch 77/100
# 20/20 [==============================] - 7s 374ms/step - loss: 2.1109e-05 - accuracy: 1.0000 - val_loss: 2.1229 - val_accuracy: 0.7590
# Epoch 78/100
# 20/20 [==============================] - 7s 372ms/step - loss: 2.0483e-05 - accuracy: 1.0000 - val_loss: 2.1285 - val_accuracy: 0.7600
# Epoch 79/100
# 20/20 [==============================] - 7s 369ms/step - loss: 1.9892e-05 - accuracy: 1.0000 - val_loss: 2.1336 - val_accuracy: 0.7600
# Epoch 80/100
# 20/20 [==============================] - 7s 366ms/step - loss: 1.9297e-05 - accuracy: 1.0000 - val_loss: 2.1382 - val_accuracy: 0.7600
# Epoch 81/100
# 20/20 [==============================] - 7s 368ms/step - loss: 1.8788e-05 - accuracy: 1.0000 - val_loss: 2.1434 - val_accuracy: 0.7590
# Epoch 82/100
# 20/20 [==============================] - 7s 372ms/step - loss: 1.8234e-05 - accuracy: 1.0000 - val_loss: 2.1481 - val_accuracy: 0.7590
# Epoch 83/100
# 20/20 [==============================] - 7s 369ms/step - loss: 1.7739e-05 - accuracy: 1.0000 - val_loss: 2.1525 - val_accuracy: 0.7590
# Epoch 84/100
# 20/20 [==============================] - 7s 366ms/step - loss: 1.7295e-05 - accuracy: 1.0000 - val_loss: 2.1574 - val_accuracy: 0.7590
# Epoch 85/100
# 20/20 [==============================] - 7s 369ms/step - loss: 1.6807e-05 - accuracy: 1.0000 - val_loss: 2.1619 - val_accuracy: 0.7590
# Epoch 86/100
# 20/20 [==============================] - 7s 369ms/step - loss: 1.6385e-05 - accuracy: 1.0000 - val_loss: 2.1664 - val_accuracy: 0.7590
# Epoch 87/100
# 20/20 [==============================] - 7s 373ms/step - loss: 1.5974e-05 - accuracy: 1.0000 - val_loss: 2.1705 - val_accuracy: 0.7590
# Epoch 88/100
# 20/20 [==============================] - 7s 368ms/step - loss: 1.5572e-05 - accuracy: 1.0000 - val_loss: 2.1760 - val_accuracy: 0.7590
# Epoch 89/100
# 20/20 [==============================] - 7s 371ms/step - loss: 1.5154e-05 - accuracy: 1.0000 - val_loss: 2.1806 - val_accuracy: 0.7590
# Epoch 90/100
# 20/20 [==============================] - 7s 368ms/step - loss: 1.4778e-05 - accuracy: 1.0000 - val_loss: 2.1840 - val_accuracy: 0.7590
# Epoch 91/100
# 20/20 [==============================] - 7s 370ms/step - loss: 1.4405e-05 - accuracy: 1.0000 - val_loss: 2.1884 - val_accuracy: 0.7590
# Epoch 92/100
# 20/20 [==============================] - 7s 368ms/step - loss: 1.4064e-05 - accuracy: 1.0000 - val_loss: 2.1928 - val_accuracy: 0.7590
# Epoch 93/100
# 20/20 [==============================] - 7s 369ms/step - loss: 1.3732e-05 - accuracy: 1.0000 - val_loss: 2.1975 - val_accuracy: 0.7590
# Epoch 94/100
# 20/20 [==============================] - 7s 368ms/step - loss: 1.3373e-05 - accuracy: 1.0000 - val_loss: 2.2011 - val_accuracy: 0.7590
# Epoch 95/100
# 20/20 [==============================] - 7s 369ms/step - loss: 1.3075e-05 - accuracy: 1.0000 - val_loss: 2.2062 - val_accuracy: 0.7590
# Epoch 96/100
# 20/20 [==============================] - 7s 374ms/step - loss: 1.2749e-05 - accuracy: 1.0000 - val_loss: 2.2099 - val_accuracy: 0.7590
# Epoch 97/100
# 20/20 [==============================] - 7s 373ms/step - loss: 1.2474e-05 - accuracy: 1.0000 - val_loss: 2.2143 - val_accuracy: 0.7590
# Epoch 98/100
# 20/20 [==============================] - 7s 369ms/step - loss: 1.2178e-05 - accuracy: 1.0000 - val_loss: 2.2174 - val_accuracy: 0.7590
# Epoch 99/100
# 20/20 [==============================] - 7s 371ms/step - loss: 1.1895e-05 - accuracy: 1.0000 - val_loss: 2.2213 - val_accuracy: 0.7590
# Epoch 100/100
# 20/20 [==============================] - 7s 369ms/step - loss: 1.1629e-05 - accuracy: 1.0000 - val_loss: 2.2257 - val_accuracy: 0.7590

# %%
# Visualize the result.
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.savefig('./foo.png')
plt.show()

# %%
# Get the dataset.
image_batch, label_batch = train_data_gen[0]

# Make predictions.
plt.figure(figsize=(20, 20))
for i in range(10):
  plt.subplot(5, 5, i + 1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)

  img = image_batch[i]
  plt.imshow(img)

  img = np.array([img])
  predict_image = model.predict(img)
  predict_id = np.argmax(predict_image[0])
  label = "Cat"
  if predict_id == 1:
    label = "Dog"
  plt.xlabel("{} ({}%)".format(label, 100 * np.max(predict_image)))
plt.show()
