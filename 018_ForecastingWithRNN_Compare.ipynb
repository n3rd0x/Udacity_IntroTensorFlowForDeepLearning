# %%
# Education - Udacity "Intro to TensorFlow for Deep Learning"
# Module: Forecasting with Recurrent Neural Network (Sequence to Vector) and (Sequence to Sequence)
# REF: https://colab.research.google.com/github/tensorflow/examples/blob/master/courses/udacity_intro_to_tensorflow_for_deep_learning/l08c06_forecasting_with_rnn.ipynb

# %%
# Import packages.
from __future__ import absolute_import, division, print_function, unicode_literals
import numpy as np
import matplotlib.pyplot as plt

# Using version 2.x of Tensorflow.
try:
  # Use the %tensorflow_version magic if in colab.
  # %tensorflow_version 2.x
except Exception:
  pass

# Tensorflow.
import tensorflow as tf

# Print Tensorflow version.
print('TensorFlow Version:', tf.__version__)
# Out:
# TensorFlow 2.x selected.
# TensorFlow Version: 2.1.0

# %%
# ====================
# Helper Function
# ====================
# Plot serie.
def plot_series(time, series, format="-", start=0, end=None, label=None):
  plt.plot(time[start:end], series[start:end], format, label=label)
  plt.xlabel("Time")
  plt.ylabel("Value")
  if label:
    plt.legend(fontsize=14)
  plt.grid(True)


# Trend.
def trend(time, slope=0):
  return slope * time


# Seasonal pattern.
def seasonal_pattern(season_time):
  # Just an arbitrary pattern.
  return np.where(season_time < 0.4, np.cos(season_time * 2 * np.pi), 1 / np.exp(3 * season_time))


# Seasonality.
def seasonality(time, period, amplitude=1, phase=0):
  # Repeats the same pattern at each period.
  season_time = ((time + phase) % period) / period
  return amplitude * seasonal_pattern(season_time)


# White noise.
def white_noise(time, noise_level=1, seed=None):
  rnd = np.random.RandomState(seed)
  return rnd.randn(len(time)) * noise_level


# Simple window dataset.
def window_dataset(series, window_size, batch_size = 32, shuffle_buffer = 1000):
  # Create a dataset of tensors.
  dataset = tf.data.Dataset.from_tensor_slices(series)

  # Drop remaining values so we get same size.
  dataset = dataset.window(window_size + 1, shift = 1, drop_remainder = True)

  # The dataset contains a tensor with size of 5.
  dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))

  # Split into two arrays, one for inputs and one for labels.
  dataset = dataset.map(lambda window: (window[ : -1], window[-1 : ]))

  # Shuffle the dataset.
  dataset = dataset.shuffle(shuffle_buffer)

  # Create batches. The 'prefetch' indicates the Tensorflow will
  # fetch the data while working, so we always have data to use.
  dataset = dataset.batch(batch_size).prefetch(1)

  return dataset


# Sequence to sequence dataset.
def seq2seq_window_dataset(series, window_size, batch_size = 32, shuffle_buffer = 1000):
  series = tf.expand_dims(series, axis = -1)
  ds = tf.data.Dataset.from_tensor_slices(series)
  ds = ds.window(window_size + 1, shift = 1, drop_remainder = True)
  ds = ds.flat_map(lambda w: w.batch(window_size + 1))
  ds = ds.shuffle(shuffle_buffer)
  ds = ds.map(lambda w: (w[:-1], w[1:]))
  return ds.batch(batch_size).prefetch(1)


# Predict function.
def model_forecast(model, series, window_size):
  ds = tf.data.Dataset.from_tensor_slices(series)
  ds = ds.window(window_size, shift=1, drop_remainder=True)
  ds = ds.flat_map(lambda w: w.batch(window_size))
  ds = ds.batch(32).prefetch(1)
  forecast = model.predict(ds)
  return forecast

# %%
# Create dataset.
time      = np.arange(4 * 365 + 1)
slope     = 0.05
baseline  = 10
amplitude = 40
series    = baseline + trend(time, slope) + seasonality(time, period = 365, amplitude = amplitude)

noise_level = 5
noise       = white_noise(time, noise_level, seed = 42)

series += noise

plt.figure(figsize=(10, 6))
plot_series(time, series)
plt.show()

# %%
# Prepare for machine learning.
split_time    = 1000
time_train    = time[:split_time]
series_train  = series[:split_time]
time_valid    = time[split_time:]
series_valid  = series[split_time:]

SEED        = 42
WINDOW_SIZE = 30

# %%
# ==================
# RNN Forecasting (Sequence to Vector)
# ==================
tf.keras.backend.clear_session()
tf.random.set_seed(SEED)
np.random.seed(SEED)

vec_dataset_train = window_dataset(series_train, WINDOW_SIZE, batch_size = 128)
vec_dataset_valid = window_dataset(series_valid, WINDOW_SIZE, batch_size = 128)

vec_model = tf.keras.models.Sequential([
  tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis = -1), input_shape = [None]),
  tf.keras.layers.SimpleRNN(100, return_sequences = True),
  tf.keras.layers.SimpleRNN(100),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 200.0)
])

vec_model.compile(
  loss = tf.keras.losses.Huber(),
  optimizer = tf.keras.optimizers.SGD(lr = 1.5e-6, momentum = 0.9),
  metrics = ["mae"]
)

vec_early_stopping = tf.keras.callbacks.EarlyStopping(patience = 50)
vec_model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    "seqvec_checkpoint.h5",
    save_best_only = True
)

vec_model.fit(
  vec_dataset_train,
  epochs = 500,
  validation_data = vec_dataset_valid,
  callbacks = [vec_early_stopping, vec_model_checkpoint]
)

vec_model = tf.keras.models.load_model("seqvec_checkpoint.h5")

vec_rnn = model_forecast(
    vec_model,
    series[split_time - WINDOW_SIZE: - 1],
    WINDOW_SIZE
)[:, 0]
# Out:
# Epoch 1/500
# 8/8 [==============================] - 3s 408ms/step - loss: 59.3020 - mae: 60.3561 - val_loss: 42.0142 - val_mae: 42.3809
# Epoch 2/500
# 8/8 [==============================] - 1s 64ms/step - loss: 36.5803 - mae: 37.3106 - val_loss: 11.4775 - val_mae: 11.7886
# Epoch 3/500
# 8/8 [==============================] - 1s 63ms/step - loss: 23.6567 - mae: 24.0715 - val_loss: 12.7571 - val_mae: 13.0818
# Epoch 4/500
# 8/8 [==============================] - 1s 63ms/step - loss: 16.7817 - mae: 17.6512 - val_loss: 21.4763 - val_mae: 22.3445
# Epoch 5/500
# 8/8 [==============================] - 0s 61ms/step - loss: 13.7011 - mae: 14.3757 - val_loss: 10.0938 - val_mae: 10.6566
# Epoch 6/500
# 8/8 [==============================] - 0s 60ms/step - loss: 11.4010 - mae: 12.0649 - val_loss: 11.5668 - val_mae: 12.0477
# Epoch 7/500
# 8/8 [==============================] - 0s 62ms/step - loss: 11.0705 - mae: 11.4645 - val_loss: 8.4023 - val_mae: 8.9583
# Epoch 8/500
# 8/8 [==============================] - 1s 69ms/step - loss: 9.8453 - mae: 10.4364 - val_loss: 8.1328 - val_mae: 8.3870
# Epoch 9/500
# 8/8 [==============================] - 1s 74ms/step - loss: 9.3958 - mae: 9.9064 - val_loss: 5.8400 - val_mae: 6.2796
# Epoch 10/500
# 8/8 [==============================] - 1s 69ms/step - loss: 8.9630 - mae: 9.5810 - val_loss: 5.5729 - val_mae: 6.0332
# Epoch 11/500
# 8/8 [==============================] - 1s 72ms/step - loss: 8.8302 - mae: 9.4342 - val_loss: 5.4809 - val_mae: 5.9485
# Epoch 12/500
# 8/8 [==============================] - 1s 66ms/step - loss: 8.4793 - mae: 9.1302 - val_loss: 7.6239 - val_mae: 7.5611
# Epoch 13/500
# 8/8 [==============================] - 1s 65ms/step - loss: 8.2464 - mae: 8.8850 - val_loss: 6.0405 - val_mae: 6.6060
# Epoch 14/500
# 8/8 [==============================] - 1s 68ms/step - loss: 8.0174 - mae: 8.6052 - val_loss: 5.8561 - val_mae: 6.6738
# Epoch 103/500
# 8/8 [==============================] - 1s 65ms/step - loss: 4.9690 - mae: 5.4513 - val_loss: 6.1590 - val_mae: 6.8282
# Epoch 104/500
# 8/8 [==============================] - 1s 71ms/step - loss: 5.0921 - mae: 5.5781 - val_loss: 5.7516 - val_mae: 6.3497
# Epoch 105/500
# 8/8 [==============================] - 1s 66ms/step - loss: 4.9019 - mae: 5.3391 - val_loss: 5.5957 - val_mae: 6.0767
# Epoch 106/500
# 8/8 [==============================] - 1s 67ms/step - loss: 5.2797 - mae: 5.6953 - val_loss: 5.0388 - val_mae: 5.4241
# Epoch 107/500
# 8/8 [==============================] - 1s 67ms/step - loss: 4.7851 - mae: 5.3430 - val_loss: 4.9787 - val_mae: 5.4246
# Epoch 108/500
# 8/8 [==============================] - 1s 67ms/step - loss: 4.6880 - mae: 5.2099 - val_loss: 6.5895 - val_mae: 7.1295
# Epoch 109/500
# 8/8 [==============================] - 1s 71ms/step - loss: 4.8880 - mae: 5.3443 - val_loss: 5.1158 - val_mae: 5.5626
# Epoch 110/500
# 8/8 [==============================] - 1s 64ms/step - loss: 4.8759 - mae: 5.2962 - val_loss: 5.9152 - val_mae: 6.3077
# Epoch 111/500
# 8/8 [==============================] - 1s 69ms/step - loss: 4.8943 - mae: 5.3039 - val_loss: 4.8984 - val_mae: 5.4111
# Epoch 112/500
# 8/8 [==============================] - 1s 67ms/step - loss: 4.9600 - mae: 5.4268 - val_loss: 5.4896 - val_mae: 5.8614
# Epoch 113/500
# 8/8 [==============================] - 1s 71ms/step - loss: 4.9801 - mae: 5.4835 - val_loss: 5.3333 - val_mae: 5.6938
# Epoch 114/500
# 8/8 [==============================] - 1s 63ms/step - loss: 4.6993 - mae: 5.1513 - val_loss: 4.9177 - val_mae: 5.4885
# Epoch 115/500
# 8/8 [==============================] - 1s 66ms/step - loss: 5.0020 - mae: 5.4322 - val_loss: 5.4331 - val_mae: 5.9719
# Epoch 116/500
# 8/8 [==============================] - 1s 63ms/step - loss: 5.1851 - mae: 5.6866 - val_loss: 8.3071 - val_mae: 8.9622
# Epoch 117/500
# 8/8 [==============================] - 1s 68ms/step - loss: 5.5665 - mae: 6.0348 - val_loss: 4.8495 - val_mae: 5.4561
# Epoch 118/500
# 8/8 [==============================] - 1s 75ms/step - loss: 5.1567 - mae: 5.6377 - val_loss: 5.9618 - val_mae: 6.3557

# %%
# ==================
# RNN Forecasting (Sequence to Sequence)
# ==================
tf.keras.backend.clear_session()
tf.random.set_seed(SEED)
np.random.seed(SEED)

seq_dataset_train = seq2seq_window_dataset(series_train, WINDOW_SIZE, batch_size = 128)
seq_dataset_valid = seq2seq_window_dataset(series_valid, WINDOW_SIZE, batch_size = 128)

seq_model = tf.keras.models.Sequential([
  tf.keras.layers.SimpleRNN(100, return_sequences = True, input_shape = [None, 1]),
  tf.keras.layers.SimpleRNN(100, return_sequences = True),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 200.0)
])

seq_model.compile(
  loss = tf.keras.losses.Huber(),
  optimizer = tf.keras.optimizers.SGD(lr = 1e-6, momentum = 0.9),
  metrics = ["mae"]
)

seq_early_stopping = tf.keras.callbacks.EarlyStopping(patience = 10)
seq_model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    "seqseq_checkpoint.h5",
    save_best_only = True
)

seq_model.fit(
  seq_dataset_train,
  epochs = 500,
  validation_data = seq_dataset_valid,
  callbacks = [seq_early_stopping, seq_model_checkpoint]
)

seq_model = tf.keras.models.load_model("seqseq_checkpoint.h5")

seq_rnn = model_forecast(
    seq_model,
    series[..., np.newaxis],
    WINDOW_SIZE
)
seq_rnn = seq_rnn[split_time - WINDOW_SIZE:-1, -1, 0]
# Out:
# Epoch 1/500
# 8/8 [==============================] - 2s 246ms/step - loss: 55.8513 - mae: 56.2826 - val_loss: 17.6785 - val_mae: 18.0197
# Epoch 2/500
# 8/8 [==============================] - 1s 77ms/step - loss: 33.9155 - mae: 35.1114 - val_loss: 17.4471 - val_mae: 18.0774
# Epoch 3/500
# 8/8 [==============================] - 1s 80ms/step - loss: 28.3637 - mae: 28.6514 - val_loss: 35.8526 - val_mae: 36.0964
# Epoch 4/500
# 8/8 [==============================] - 1s 77ms/step - loss: 21.0046 - mae: 21.6919 - val_loss: 27.8289 - val_mae: 28.4824
# Epoch 5/500
# 8/8 [==============================] - 1s 71ms/step - loss: 17.9119 - mae: 18.5032 - val_loss: 17.8702 - val_mae: 18.4260
# Epoch 6/500
# 8/8 [==============================] - 1s 79ms/step - loss: 15.3045 - mae: 15.8192 - val_loss: 10.6282 - val_mae: 11.1624
# Epoch 7/500
# 8/8 [==============================] - 1s 74ms/step - loss: 13.8782 - mae: 14.3735 - val_loss: 8.7739 - val_mae: 9.2796
# Epoch 8/500
# 8/8 [==============================] - 1s 67ms/step - loss: 13.0289 - mae: 13.6209 - val_loss: 10.1551 - val_mae: 10.6831
# Epoch 9/500
# 8/8 [==============================] - 1s 63ms/step - loss: 12.5017 - mae: 13.0347 - val_loss: 8.8221 - val_mae: 9.3050
# Epoch 10/500
# 8/8 [==============================] - 1s 72ms/step - loss: 11.7843 - mae: 12.4174 - val_loss: 8.0352 - val_mae: 8.5111
# Epoch 11/500
# 8/8 [==============================] - 1s 67ms/step - loss: 11.4571 - mae: 11.9270 - val_loss: 8.2851 - val_mae: 8.7258
# Epoch 12/500
# 8/8 [==============================] - 1s 69ms/step - loss: 11.0459 - mae: 11.5188 - val_loss: 8.1388 - val_mae: 8.3984
# Epoch 13/500
# 8/8 [==============================] - 1s 84ms/step - loss: 10.6491 - mae: 11.1769 - val_loss: 7.7866 - val_mae: 8.2141
# Epoch 14/500
# 8/8 [==============================] - 0s 62ms/step - loss: 10.3284 - mae: 10.8666 - val_loss: 7.5412 - val_mae: 8.1457
# Epoch 15/500
# 8/8 [==============================] - 1s 76ms/step - loss: 10.1402 - mae: 10.5846 - val_loss: 7.6774 - val_mae: 8.0327
# Epoch 16/500
# 8/8 [==============================] - 1s 71ms/step - loss: 9.9063 - mae: 10.3390 - val_loss: 7.5106 - val_mae: 7.9152
# Epoch 17/500
# 8/8 [==============================] - 1s 63ms/step - loss: 9.6159 - mae: 10.1225 - val_loss: 7.3284 - val_mae: 7.7785
# Epoch 18/500
# 8/8 [==============================] - 1s 77ms/step - loss: 9.4083 - mae: 9.9162 - val_loss: 7.2855 - val_mae: 7.7247
500
# 8/8 [==============================] - 1s 63ms/step - loss: 5.9354 - mae: 6.4228 - val_loss: 5.4446 - val_mae: 5.8844
# Epoch 84/500
# 8/8 [==============================] - 1s 65ms/step - loss: 5.9300 - mae: 6.4064 - val_loss: 5.3865 - val_mae: 5.8665
# Epoch 85/500
# 8/8 [==============================] - 1s 69ms/step - loss: 5.8836 - mae: 6.3913 - val_loss: 5.3660 - val_mae: 5.8635
# Epoch 86/500
# 8/8 [==============================] - 0s 61ms/step - loss: 5.9013 - mae: 6.3781 - val_loss: 5.3698 - val_mae: 5.8302
# Epoch 87/500
# 8/8 [==============================] - 1s 64ms/step - loss: 5.8897 - mae: 6.3675 - val_loss: 5.5144 - val_mae: 6.0156
# Epoch 88/500
# 8/8 [==============================] - 1s 69ms/step - loss: 5.8720 - mae: 6.3616 - val_loss: 5.2486 - val_mae: 5.7688
# Epoch 89/500
# 8/8 [==============================] - 1s 64ms/step - loss: 5.8497 - mae: 6.3500 - val_loss: 5.5552 - val_mae: 6.0661
# Epoch 90/500
# 8/8 [==============================] - 0s 62ms/step - loss: 5.8939 - mae: 6.3488 - val_loss: 5.2505 - val_mae: 5.7532
# Epoch 91/500
# 8/8 [==============================] - 1s 65ms/step - loss: 5.8791 - mae: 6.3332 - val_loss: 5.4019 - val_mae: 5.8869
# Epoch 92/500
# 8/8 [==============================] - 1s 63ms/step - loss: 5.8247 - mae: 6.3067 - val_loss: 5.2892 - val_mae: 5.7609
# Epoch 93/500
# 8/8 [==============================] - 0s 61ms/step - loss: 5.8213 - mae: 6.2929 - val_loss: 5.4045 - val_mae: 5.9055
# Epoch 94/500
# 8/8 [==============================] - 1s 69ms/step - loss: 5.7827 - mae: 6.2763 - val_loss: 5.2437 - val_mae: 5.7578
# Epoch 95/500
# 8/8 [==============================] - 1s 64ms/step - loss: 5.7753 - mae: 6.2654 - val_loss: 5.3492 - val_mae: 5.8862
# Epoch 96/500
# 8/8 [==============================] - 1s 64ms/step - loss: 5.7687 - mae: 6.2523 - val_loss: 5.3568 - val_mae: 5.8154
# Epoch 97/500
# 8/8 [==============================] - 1s 64ms/step - loss: 5.7431 - mae: 6.2397 - val_loss: 5.4340 - val_mae: 5.9087
# Epoch 98/500
# 8/8 [==============================] - 1s 64ms/step - loss: 5.7477 - mae: 6.2446 - val_loss: 5.2697 - val_mae: 5.6961
# Epoch 99/500
# 8/8 [==============================] - 1s 66ms/step - loss: 5.7334 - mae: 6.2160 - val_loss: 5.3113 - val_mae: 5.7947
# Epoch 100/500
# 8/8 [==============================] - 0s 60ms/step - loss: 5.7162 - mae: 6.2106 - val_loss: 5.2733 - val_mae: 5.7683
# Epoch 101/500
# 8/8 [==============================] - 1s 64ms/step - loss: 5.6890 - mae: 6.1936 - val_loss: 5.2871 - val_mae: 5.7706
# Epoch 102/500
# 8/8 [==============================] - 1s 63ms/step - loss: 5.6865 - mae: 6.1796 - val_loss: 5.3931 - val_mae: 5.8152
# Epoch 103/500
# 8/8 [==============================] - 0s 62ms/step - loss: 5.6580 - mae: 6.1663 - val_loss: 5.2540 - val_mae: 5.7745
# Epoch 104/500
# 8/8 [==============================] - 1s 66ms/step - loss: 5.6964 - mae: 6.1536 - val_loss: 5.2200 - val_mae: 5.7325
# Epoch 105/500
# 8/8 [==============================] - 0s 60ms/step - loss: 5.7060 - mae: 6.1403 - val_loss: 5.2741 - val_mae: 5.8110
# Epoch 106/500
# 8/8 [==============================] - 1s 68ms/step - loss: 5.6725 - mae: 6.1271 - val_loss: 5.2017 - val_mae: 5.6685
# Epoch 107/500
# 8/8 [==============================] - 1s 64ms/step - loss: 5.6408 - mae: 6.1214 - val_loss: 5.3760 - val_mae: 5.8138
# Epoch 108/500
# 8/8 [==============================] - 1s 63ms/step - loss: 5.6541 - mae: 6.1075 - val_loss: 5.3060 - val_mae: 5.7576
# Epoch 109/500
# 8/8 [==============================] - 1s 68ms/step - loss: 5.6133 - mae: 6.0943 - val_loss: 5.2524 - val_mae: 5.7214
# Epoch 110/500
# 8/8 [==============================] - 1s 79ms/step - loss: 5.5984 - mae: 6.0801 - val_loss: 5.1861 - val_mae: 5.6820
# Epoch 111/500
# 8/8 [==============================] - 1s 72ms/step - loss: 5.6278 - mae: 6.0738 - val_loss: 5.3553 - val_mae: 5.8282
# Epoch 112/500
# 8/8 [==============================] - 1s 71ms/step - loss: 5.6185 - mae: 6.0598 - val_loss: 5.1867 - val_mae: 5.6513
# Epoch 113/500
# 8/8 [==============================] - 1s 72ms/step - loss: 5.5832 - mae: 6.0503 - val_loss: 5.3155 - val_mae: 5.7741
# Epoch 114/500
# 8/8 [==============================] - 1s 72ms/step - loss: 5.5659 - mae: 6.0355 - val_loss: 5.2853 - val_mae: 5.7452
# Epoch 115/500
# 8/8 [==============================] - 1s 69ms/step - loss: 5.5550 - mae: 6.0242 - val_loss: 5.2186 - val_mae: 5.6990
# Epoch 116/500
# 8/8 [==============================] - 1s 76ms/step - loss: 5.5115 - mae: 6.0123 - val_loss: 5.1687 - val_mae: 5.6880
# Epoch 117/500
# 8/8 [==============================] - 1s 73ms/step - loss: 5.5226 - mae: 6.0023 - val_loss: 5.1601 - val_mae: 5.6806
# Epoch 118/500
# 8/8 [==============================] - 1s 75ms/step - loss: 5.5183 - mae: 5.9966 - val_loss: 5.3029 - val_mae: 5.7425
# Epoch 119/500
# 8/8 [==============================] - 1s 79ms/step - loss: 5.5245 - mae: 5.9848 - val_loss: 5.2220 - val_mae: 5.6341
# Epoch 120/500
# 8/8 [==============================] - 1s 70ms/step - loss: 5.4806 - mae: 5.9793 - val_loss: 5.2878 - val_mae: 5.7136
# Epoch 121/500
# 8/8 [==============================] - 1s 70ms/step - loss: 5.4825 - mae: 5.9698 - val_loss: 5.2148 - val_mae: 5.7092
# Epoch 122/500
# 8/8 [==============================] - 1s 76ms/step - loss: 5.4931 - mae: 5.9603 - val_loss: 5.1480 - val_mae: 5.6836
# Epoch 123/500
# 8/8 [==============================] - 1s 67ms/step - loss: 5.4699 - mae: 5.9427 - val_loss: 5.1792 - val_mae: 5.7103
# Epoch 124/500
# 8/8 [==============================] - 1s 69ms/step - loss: 5.4665 - mae: 5.9309 - val_loss: 5.1589 - val_mae: 5.6396
# Epoch 125/500
# 8/8 [==============================] - 1s 70ms/step - loss: 5.4465 - mae: 5.9188 - val_loss: 5.2403 - val_mae: 5.7024
# Epoch 126/500
# 8/8 [==============================] - 1s 73ms/step - loss: 5.4472 - mae: 5.9083 - val_loss: 5.1686 - val_mae: 5.6640
# Epoch 127/500
# 8/8 [==============================] - 1s 71ms/step - loss: 5.4259 - mae: 5.8979 - val_loss: 5.1556 - val_mae: 5.6217
# Epoch 128/500
# 8/8 [==============================] - 1s 76ms/step - loss: 5.3968 - mae: 5.8928 - val_loss: 5.2615 - val_mae: 5.7583
# Epoch 129/500
# 8/8 [==============================] - 1s 65ms/step - loss: 5.4104 - mae: 5.8810 - val_loss: 5.1096 - val_mae: 5.6117
# Epoch 130/500
# 8/8 [==============================] - 1s 68ms/step - loss: 5.3607 - mae: 5.8681 - val_loss: 5.2225 - val_mae: 5.6829
# Epoch 131/500
# 8/8 [==============================] - 1s 70ms/step - loss: 5.3659 - mae: 5.8576 - val_loss: 5.1866 - val_mae: 5.6872
# Epoch 132/500
# 8/8 [==============================] - 1s 74ms/step - loss: 5.3826 - mae: 5.8496 - val_loss: 5.1490 - val_mae: 5.6465
# Epoch 133/500
# 8/8 [==============================] - 1s 70ms/step - loss: 5.3794 - mae: 5.8393 - val_loss: 5.1083 - val_mae: 5.5950
# Epoch 134/500
# 8/8 [==============================] - 1s 72ms/step - loss: 5.3521 - mae: 5.8293 - val_loss: 5.1538 - val_mae: 5.6376
# Epoch 135/500
# 8/8 [==============================] - 1s 67ms/step - loss: 5.3285 - mae: 5.8225 - val_loss: 5.1202 - val_mae: 5.6016
# Epoch 136/500
# 8/8 [==============================] - 1s 71ms/step - loss: 5.3966 - mae: 5.8189 - val_loss: 5.2983 - val_mae: 5.8202
# Epoch 137/500
# 8/8 [==============================] - 1s 70ms/step - loss: 5.3461 - mae: 5.8101 - val_loss: 5.0645 - val_mae: 5.6001
# Epoch 138/500
# 8/8 [==============================] - 1s 72ms/step - loss: 5.3074 - mae: 5.7983 - val_loss: 5.2570 - val_mae: 5.7213
# Epoch 139/500
# 8/8 [==============================] - 1s 75ms/step - loss: 5.3062 - mae: 5.7869 - val_loss: 5.1197 - val_mae: 5.5661
# Epoch 140/500
# 8/8 [==============================] - 1s 64ms/step - loss: 5.2997 - mae: 5.7787 - val_loss: 5.2172 - val_mae: 5.7301
# Epoch 141/500
# 8/8 [==============================] - 1s 71ms/step - loss: 5.3017 - mae: 5.7710 - val_loss: 5.1280 - val_mae: 5.5731
# Epoch 142/500
# 8/8 [==============================] - 1s 66ms/step - loss: 5.2892 - mae: 5.7563 - val_loss: 5.1824 - val_mae: 5.6691
# Epoch 143/500
# 8/8 [==============================] - 1s 71ms/step - loss: 5.2684 - mae: 5.7453 - val_loss: 5.1202 - val_mae: 5.6114
# Epoch 144/500
# 8/8 [==============================] - 1s 71ms/step - loss: 5.2645 - mae: 5.7374 - val_loss: 5.1674 - val_mae: 5.6156
# Epoch 145/500
# 8/8 [==============================] - 1s 70ms/step - loss: 5.2304 - mae: 5.7297 - val_loss: 5.0300 - val_mae: 5.5416
# Epoch 146/500
# 8/8 [==============================] - 1s 69ms/step - loss: 5.2302 - mae: 5.7209 - val_loss: 5.1571 - val_mae: 5.5954
# Epoch 147/500
# 8/8 [==============================] - 1s 66ms/step - loss: 5.2465 - mae: 5.7138 - val_loss: 5.2335 - val_mae: 5.7155
# Epoch 148/500
# 8/8 [==============================] - 1s 71ms/step - loss: 5.2463 - mae: 5.7112 - val_loss: 5.0695 - val_mae: 5.4999
# Epoch 149/500
# 8/8 [==============================] - 1s 72ms/step - loss: 5.2406 - mae: 5.7046 - val_loss: 5.3396 - val_mae: 5.8294
# Epoch 150/500
# 8/8 [==============================] - 1s 69ms/step - loss: 5.2339 - mae: 5.6968 - val_loss: 5.0290 - val_mae: 5.5237
# Epoch 151/500
# 8/8 [==============================] - 1s 63ms/step - loss: 5.2091 - mae: 5.6773 - val_loss: 5.0745 - val_mae: 5.5445
# Epoch 152/500
# 8/8 [==============================] - 1s 68ms/step - loss: 5.1796 - mae: 5.6707 - val_loss: 5.1758 - val_mae: 5.6299
# Epoch 153/500
# 8/8 [==============================] - 1s 65ms/step - loss: 5.1676 - mae: 5.6612 - val_loss: 5.0825 - val_mae: 5.5453
# Epoch 154/500
# 8/8 [==============================] - 1s 70ms/step - loss: 5.1963 - mae: 5.6528 - val_loss: 5.2104 - val_mae: 5.6627
# Epoch 155/500
# 8/8 [==============================] - 1s 70ms/step - loss: 5.1919 - mae: 5.6493 - val_loss: 5.0479 - val_mae: 5.5102
# Epoch 156/500
# 8/8 [==============================] - 1s 71ms/step - loss: 5.1769 - mae: 5.6419 - val_loss: 5.1549 - val_mae: 5.6269
# Epoch 157/500
# 8/8 [==============================] - 1s 70ms/step - loss: 5.1762 - mae: 5.6378 - val_loss: 4.9962 - val_mae: 5.4931
# Epoch 158/500
# 8/8 [==============================] - 1s 69ms/step - loss: 5.1468 - mae: 5.6330 - val_loss: 5.1921 - val_mae: 5.6579
# Epoch 159/500
# 8/8 [==============================] - 1s 67ms/step - loss: 5.1325 - mae: 5.6222 - val_loss: 5.0146 - val_mae: 5.5161
# Epoch 160/500
# 8/8 [==============================] - 1s 64ms/step - loss: 5.1332 - mae: 5.6056 - val_loss: 5.1307 - val_mae: 5.5564
# Epoch 161/500
# 8/8 [==============================] - 1s 63ms/step - loss: 5.1288 - mae: 5.6010 - val_loss: 5.1063 - val_mae: 5.5699
# Epoch 162/500
# 8/8 [==============================] - 1s 72ms/step - loss: 5.1359 - mae: 5.5961 - val_loss: 5.0385 - val_mae: 5.4942
# Epoch 163/500
# 8/8 [==============================] - 1s 63ms/step - loss: 5.1085 - mae: 5.5883 - val_loss: 5.0393 - val_mae: 5.5616
# Epoch 164/500
# 8/8 [==============================] - 1s 68ms/step - loss: 5.1003 - mae: 5.5745 - val_loss: 5.0195 - val_mae: 5.4990
# Epoch 165/500
# 8/8 [==============================] - 1s 68ms/step - loss: 5.0987 - mae: 5.5682 - val_loss: 5.0871 - val_mae: 5.5647
# Epoch 166/500
# 8/8 [==============================] - 1s 69ms/step - loss: 5.0794 - mae: 5.5650 - val_loss: 5.0717 - val_mae: 5.5398
# Epoch 167/500
# 8/8 [==============================] - 1s 67ms/step - loss: 5.0839 - mae: 5.5591 - val_loss: 5.1230 - val_mae: 5.5197

# %%
# Plot the forecasts.
plt.figure(figsize = (10, 6))
plot_series(time_valid, series_valid, label = "Time series")
plot_series(time_valid, vec_rnn, label = "Seq2Vec")
plot_series(time_valid, seq_rnn, label = "Seq2Seq")

vec_mae = tf.keras.metrics.mean_absolute_error(series_valid, vec_rnn).numpy()
seq_mae = tf.keras.metrics.mean_absolute_error(series_valid, seq_rnn).numpy()
print("MAE: (Seq2Vec: " + str(vec_mae) + ") vs (Seq2Seq: " + str(seq_mae) + ")")
# Out:
# MAE: (Seq2Vec: 5.4141636) vs (Seq2Seq: 5.0920377)
